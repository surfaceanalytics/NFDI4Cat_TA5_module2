# %% [markdown]
# # Example of retrieving data from an API of a Web App
# <h3> Imports</h3>
# Let's import first the needed libraries

# %%
import requests
import csv
import json
import pandas as pd

# %% [markdown]
# <h3> Setting up the request </h3>
# Now, in order to securely connect with the API, wee need an access token. I have generated one here for demo purposes. The access token must be passed to the server in the header of the http request.

# %%
token = '796da693d7c232875342491039e21ad6e60b6715'

head = {'Authorization': 'token {}'.format(token)}

# %% [markdown]
# Then we will store all the useful API endpoints as variables.

# %%
sample_url = 'https://demo.surface-analytics.com/api/sample/'
results_url = 'https://demo.surface-analytics.com/api/result/'
study_url = 'https://demo.surface-analytics.com/api/study/'

# %% [markdown]
# <h3> Making a request </h3>
# Now we aill make a request to one of the endpoints and see what the server returns to us.
# In this case, we will get a list of all samples in the database.

# %%
endpoint = sample_url
response = requests.get(endpoint, headers=head)
samples = response.json()
# Out:
# [{'id': 1, 'label': 'MG-001-01', 'name': None, 'parent': None, 'date_created': '2021-09-21 13:40:18', 'state': 1, 'sample_form': None, 'mass': None, 'mass_unit': "('milligrams', 'Milligrams')", 'created_by': 1}, {'id': 2, 'label': 'MG-001-02', 'name': 'Annealed Pd', 'parent': 1, 'date_created': '2021-09-21 13:40:43', 'state': 4, 'sample_form': None, 'mass': None, 'mass_unit': "('milligrams', 'Milligrams')", 'created_by': 1}, {'id': 3, 'label': 'MG-001-03', 'name': 'Activated Pd', 'parent': 2, 'date_created': '2021-09-21 13:41:00', 'state': 3, 'sample_form': None, 'mass': None, 'mass_unit': "('milligrams', 'Milligrams')", 'created_by': 1}, {'id': 4, 'label': 'MG-001-04', 'name': 'Used Pd', 'parent': None, 'date_created': '2021-09-21 13:41:18', 'state': 3, 'sample_form': None, 'mass': None, 'mass_unit': "('milligrams', 'Milligrams')", 'created_by': 1}]

# %% [markdown]
# Great! It worked. You can see it is not so easy to read, but what we got is a list of dictionaries, containis metadata about the samples.
# Let's make it look a little prettier.

# %%
print(json.dumps(samples, indent=2))
# Out:
# [
#   {
#     "id": 1,
#     "label": "MG-001-01",
#     "name": null,
#     "parent": null,
#     "date_created": "2021-09-21 13:40:18",
#     "state": 1,
#     "sample_form": null,
#     "mass": null,
#     "mass_unit": "('milligrams', 'Milligrams')",
#     "created_by": 1
#   },
#   {
#     "id": 2,
#     "label": "MG-001-02",
#     "name": "Annealed Pd",
#     "parent": 1,
#     "date_created": "2021-09-21 13:40:43",
#     "state": 4,
#     "sample_form": null,
#     "mass": null,
#     "mass_unit": "('milligrams', 'Milligrams')",
#     "created_by": 1
#   },
#   {
#     "id": 3,
#     "label": "MG-001-03",
#     "name": "Activated Pd",
#     "parent": 2,
#     "date_created": "2021-09-21 13:41:00",
#     "state": 3,
#     "sample_form": null,
#     "mass": null,
#     "mass_unit": "('milligrams', 'Milligrams')",
#     "created_by": 1
#   },
#   {
#     "id": 4,
#     "label": "MG-001-04",
#     "name": "Used Pd",
#     "parent": null,
#     "date_created": "2021-09-21 13:41:18",
#     "state": 3,
#     "sample_form": null,
#     "mass": null,
#     "mass_unit": "('milligrams', 'Milligrams')",
#     "created_by": 1
#   }
# ]

# %% [markdown]
# That's better.
# Alternatively, we could structure it into a dataframe.
#
# <h3> Reformatting into a Dataframe </h3>

# %%
samples_df = pd.DataFrame(samples)

# %%
display(samples_df)
# Out:
#    id      label          name  parent         date_created  state  \
# 0   1  MG-001-01          None     NaN  2021-09-21 13:40:18      1
# 1   2  MG-001-02   Annealed Pd     1.0  2021-09-21 13:40:43      4
# 2   3  MG-001-03  Activated Pd     2.0  2021-09-21 13:41:00      3
# 3   4  MG-001-04       Used Pd     NaN  2021-09-21 13:41:18      3
#
#   sample_form  mass                     mass_unit  created_by
# 0        None  None  ('milligrams', 'Milligrams')           1
# 1        None  None  ('milligrams', 'Milligrams')           1
# 2        None  None  ('milligrams', 'Milligrams')           1
# 3        None  None  ('milligrams', 'Milligrams')           1

# %% [markdown]
# Cool.
# Now let's try getting some other data.
# <h3> Nested results </h3>

# %%
endpoint = results_url
response = requests.get(endpoint, headers=head)
results = response.json()
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "id": "2bfd5001-6ca6-4dbf-a6eb-a3e320f18f74",
#     "file": "http://demo.surface-analytics.com/media/uploads/Untitled_11_4.jpg",
#     "measurement_session": {
#       "id": 3,
#       "sample": {
#         "id": 1,
#         "label": "MG-001-01",
#         "name": null,
#         "parent": null,
#         "date_created": "2021-09-21 13:40:18",
#         "state": 1,
#         "sample_form": null,
#         "mass": null,
#         "mass_unit": "('milligrams', 'Milligrams')",
#         "created_by": 1
#       },
#       "study": {
#         "id": 1,
#         "name": "study",
#         "date_created": "2021-09-21 13:40:08",
#         "samples": [
#           {
#             "id": 1,
#             "label": "MG-001-01",
#             "name": null,
#             "measurement_sessions": [
#               {
#                 "id": 1,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 2,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 6,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 7,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 3,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": "cdec2073-dddf-487f-a88e-9911abf516ed",
#                 "status": "in progress"
#               },
#               {
#                 "id": 5,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": "7b0f415e-5436-4dd2-8e37-556bfab1aac1",
#                 "status": "complete"
#               },
#               {
#                 "id": 4,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": "b0e210ed-495e-4e0f-84bd-78eb270fac70",
#                 "status": "complete"
#               }
#             ]
#           },
#           {
#             "id": 2,
#             "label": "MG-001-02",
#             "name": "Annealed Pd",
#             "measurement_sessions": [
#               {
#                 "id": 8,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 9,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 10,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 11,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 12,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 13,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 14,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               }
#             ]
#           },
#           {
#             "id": 3,
#             "label": "MG-001-03",
#             "name": "Activated Pd",
#             "measurement_sessions": [
#               {
#                 "id": 15,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 16,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 17,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 18,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 19,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 20,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 21,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               }
#             ]
#           },
#           {
#             "id": 4,
#             "label": "MG-001-04",
#             "name": "Used Pd",
#             "measurement_sessions": [
#               {
#                 "id": 22,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 23,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 24,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 25,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 26,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 27,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 28,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               }
#             ]
#           }
#         ],
#         "configuration": 1
#       },
#       "method": {
#         "id": 3,
#         "name": "GC"
#       },
#       "instrument": {
#         "name": "Agilent 7000D",
#         "id": "cdec2073-dddf-487f-a88e-9911abf516ed",
#         "method": [
#           3
#         ],
#         "laboratory": null,
#         "description": ""
#       },
#       "status": "in progress"
#     },
#     "filename": "Untitled_11_4.jpg",
#     "date_created": "2021-09-21 13:41:40",
#     "method": {
#       "id": 3,
#       "name": "GC"
#     }
#   },
#   {
#     "id": "d0136a6c-21c7-453e-956c-b13c19d8aeba",
#     "file": "http://demo.surface-analytics.com/media/uploads/Untitled_13.jpg",
#     "measurement_session": {
#       "id": 5,
#       "sample": {
#         "id": 1,
#         "label": "MG-001-01",
#         "name": null,
#         "parent": null,
#         "date_created": "2021-09-21 13:40:18",
#         "state": 1,
#         "sample_form": null,
#         "mass": null,
#         "mass_unit": "('milligrams', 'Milligrams')",
#         "created_by": 1
#       },
#       "study": {
#         "id": 1,
#         "name": "study",
#         "date_created": "2021-09-21 13:40:08",
#         "samples": [
#           {
#             "id": 1,
#             "label": "MG-001-01",
#             "name": null,
#             "measurement_sessions": [
#               {
#                 "id": 1,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 2,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 6,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 7,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 3,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": "cdec2073-dddf-487f-a88e-9911abf516ed",
#                 "status": "in progress"
#               },
#               {
#                 "id": 5,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": "7b0f415e-5436-4dd2-8e37-556bfab1aac1",
#                 "status": "complete"
#               },
#               {
#                 "id": 4,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": "b0e210ed-495e-4e0f-84bd-78eb270fac70",
#                 "status": "complete"
#               }
#             ]
#           },
#           {
#             "id": 2,
#             "label": "MG-001-02",
#             "name": "Annealed Pd",
#             "measurement_sessions": [
#               {
#                 "id": 8,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 9,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 10,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 11,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 12,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 13,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 14,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               }
#             ]
#           },
#           {
#             "id": 3,
#             "label": "MG-001-03",
#             "name": "Activated Pd",
#             "measurement_sessions": [
#               {
#                 "id": 15,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 16,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 17,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 18,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 19,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 20,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 21,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               }
#             ]
#           },
#           {
#             "id": 4,
#             "label": "MG-001-04",
#             "name": "Used Pd",
#             "measurement_sessions": [
#               {
#                 "id": 22,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 23,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 24,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 25,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 26,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 27,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 28,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               }
#             ]
#           }
#         ],
#         "configuration": 1
#       },
#       "method": {
#         "id": 5,
#         "name": "IR"
#       },
#       "instrument": {
#         "name": "Alpha II",
#         "id": "7b0f415e-5436-4dd2-8e37-556bfab1aac1",
#         "method": [
#           5
#         ],
#         "laboratory": null,
#         "description": ""
#       },
#       "status": "complete"
#     },
#     "filename": "Untitled_13.jpg",
#     "date_created": "2021-09-21 13:41:58",
#     "method": {
#       "id": 5,
#       "name": "IR"
#     }
#   },
#   {
#     "id": "47c8e7db-a9e1-4977-b260-dde2df2a18bd",
#     "file": "http://demo.surface-analytics.com/media/uploads/Untitled_11_1.jpg",
#     "measurement_session": {
#       "id": 4,
#       "sample": {
#         "id": 1,
#         "label": "MG-001-01",
#         "name": null,
#         "parent": null,
#         "date_created": "2021-09-21 13:40:18",
#         "state": 1,
#         "sample_form": null,
#         "mass": null,
#         "mass_unit": "('milligrams', 'Milligrams')",
#         "created_by": 1
#       },
#       "study": {
#         "id": 1,
#         "name": "study",
#         "date_created": "2021-09-21 13:40:08",
#         "samples": [
#           {
#             "id": 1,
#             "label": "MG-001-01",
#             "name": null,
#             "measurement_sessions": [
#               {
#                 "id": 1,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 2,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 6,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 7,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 3,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": "cdec2073-dddf-487f-a88e-9911abf516ed",
#                 "status": "in progress"
#               },
#               {
#                 "id": 5,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": "7b0f415e-5436-4dd2-8e37-556bfab1aac1",
#                 "status": "complete"
#               },
#               {
#                 "id": 4,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": "b0e210ed-495e-4e0f-84bd-78eb270fac70",
#                 "status": "complete"
#               }
#             ]
#           },
#           {
#             "id": 2,
#             "label": "MG-001-02",
#             "name": "Annealed Pd",
#             "measurement_sessions": [
#               {
#                 "id": 8,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 9,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 10,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 11,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 12,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 13,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 14,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               }
#             ]
#           },
#           {
#             "id": 3,
#             "label": "MG-001-03",
#             "name": "Activated Pd",
#             "measurement_sessions": [
#               {
#                 "id": 15,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 16,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 17,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 18,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 19,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 20,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 21,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               }
#             ]
#           },
#           {
#             "id": 4,
#             "label": "MG-001-04",
#             "name": "Used Pd",
#             "measurement_sessions": [
#               {
#                 "id": 22,
#                 "method": {
#                   "id": 1,
#                   "name": "XPS"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 23,
#                 "method": {
#                   "id": 2,
#                   "name": "XRD"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 24,
#                 "method": {
#                   "id": 3,
#                   "name": "GC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 25,
#                 "method": {
#                   "id": 4,
#                   "name": "HPLC"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 26,
#                 "method": {
#                   "id": 5,
#                   "name": "IR"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 27,
#                 "method": {
#                   "id": 6,
#                   "name": "Raman"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               },
#               {
#                 "id": 28,
#                 "method": {
#                   "id": 7,
#                   "name": "ICP"
#                 },
#                 "instrument": null,
#                 "status": "not started"
#               }
#             ]
#           }
#         ],
#         "configuration": 1
#       },
#       "method": {
#         "id": 4,
#         "name": "HPLC"
#       },
#       "instrument": {
#         "name": "Vanquish Core",
#         "id": "b0e210ed-495e-4e0f-84bd-78eb270fac70",
#         "method": [
#           4
#         ],
#         "laboratory": null,
#         "description": ""
#       },
#       "status": "complete"
#     },
#     "filename": "Untitled_11_1.jpg",
#     "date_created": "2021-09-21 13:42:16",
#     "method": {
#       "id": 4,
#       "name": "HPLC"
#     }
#   }
# ]

# %% [markdown]
# Looks good. But in this case, the results are nested.
# How will this look in our dataframe?

# %%
results_df = pd.DataFrame(results)
display(results_df)
# Out:
#                                      id  \
# 0  2bfd5001-6ca6-4dbf-a6eb-a3e320f18f74
# 1  d0136a6c-21c7-453e-956c-b13c19d8aeba
# 2  47c8e7db-a9e1-4977-b260-dde2df2a18bd
#
#                                                 file  \
# 0  http://demo.surface-analytics.com/media/upload...
# 1  http://demo.surface-analytics.com/media/upload...
# 2  http://demo.surface-analytics.com/media/upload...
#
#                                  measurement_session           filename  \
# 0  {'id': 3, 'sample': {'id': 1, 'label': 'MG-001...  Untitled_11_4.jpg
# 1  {'id': 5, 'sample': {'id': 1, 'label': 'MG-001...    Untitled_13.jpg
# 2  {'id': 4, 'sample': {'id': 1, 'label': 'MG-001...  Untitled_11_1.jpg
#
#           date_created                     method
# 0  2021-09-21 13:41:40    {'id': 3, 'name': 'GC'}
# 1  2021-09-21 13:41:58    {'id': 5, 'name': 'IR'}
# 2  2021-09-21 13:42:16  {'id': 4, 'name': 'HPLC'}

# %% [markdown]
# Hmmmm...Well, the dataframe is not such a good representation for nested data.

# %% [markdown]
# We could us some built-in Pandas functionality to 'flatten' the nested items.

# %%
flat_results_df = pd.json_normalize(results, sep='-')
display(flat_results_df)
# Out:
#                                      id  \
# 0  2bfd5001-6ca6-4dbf-a6eb-a3e320f18f74
# 1  d0136a6c-21c7-453e-956c-b13c19d8aeba
# 2  47c8e7db-a9e1-4977-b260-dde2df2a18bd
#
#                                                 file           filename  \
# 0  http://demo.surface-analytics.com/media/upload...  Untitled_11_4.jpg
# 1  http://demo.surface-analytics.com/media/upload...    Untitled_13.jpg
# 2  http://demo.surface-analytics.com/media/upload...  Untitled_11_1.jpg
#
#           date_created  measurement_session-id  measurement_session-sample-id  \
# 0  2021-09-21 13:41:40                       3                              1
# 1  2021-09-21 13:41:58                       5                              1
# 2  2021-09-21 13:42:16                       4                              1
#
#   measurement_session-sample-label measurement_session-sample-name  \
# 0                        MG-001-01                            None
# 1                        MG-001-01                            None
# 2                        MG-001-01                            None
#
#   measurement_session-sample-parent measurement_session-sample-date_created  \
# 0                              None                     2021-09-21 13:40:18
# 1                              None                     2021-09-21 13:40:18
# 2                              None                     2021-09-21 13:40:18
#
#    ...  measurement_session-method-id measurement_session-method-name  \
# 0  ...                              3                              GC
# 1  ...                              5                              IR
# 2  ...                              4                            HPLC
#
#   measurement_session-instrument-name     measurement_session-instrument-id  \
# 0                       Agilent 7000D  cdec2073-dddf-487f-a88e-9911abf516ed
# 1                            Alpha II  7b0f415e-5436-4dd2-8e37-556bfab1aac1
# 2                       Vanquish Core  b0e210ed-495e-4e0f-84bd-78eb270fac70
#
#    measurement_session-instrument-method  \
# 0                                    [3]
# 1                                    [5]
# 2                                    [4]
#
#    measurement_session-instrument-laboratory  \
# 0                                       None
# 1                                       None
# 2                                       None
#
#   measurement_session-instrument-description measurement_session-status  \
# 0                                                           in progress
# 1                                                              complete
# 2                                                              complete
#
#   method-id  method-name
# 0         3           GC
# 1         5           IR
# 2         4         HPLC
#
# [3 rows x 30 columns]

# %% [markdown]
# <h3> Studies </h3>
# Let's look at some more data.

# %%
endpoint = study_url
response = requests.get(endpoint, headers=head)
studies = response.json()
print(json.dumps(studies, indent=2))
# Out:
# [
#   {
#     "id": 1,
#     "name": "study",
#     "date_created": "2021-09-21 13:40:08",
#     "samples": [
#       {
#         "id": 1,
#         "label": "MG-001-01",
#         "name": null,
#         "measurement_sessions": [
#           {
#             "id": 1,
#             "method": {
#               "id": 1,
#               "name": "XPS"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 2,
#             "method": {
#               "id": 2,
#               "name": "XRD"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 6,
#             "method": {
#               "id": 6,
#               "name": "Raman"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 7,
#             "method": {
#               "id": 7,
#               "name": "ICP"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 3,
#             "method": {
#               "id": 3,
#               "name": "GC"
#             },
#             "instrument": "cdec2073-dddf-487f-a88e-9911abf516ed",
#             "status": "in progress"
#           },
#           {
#             "id": 5,
#             "method": {
#               "id": 5,
#               "name": "IR"
#             },
#             "instrument": "7b0f415e-5436-4dd2-8e37-556bfab1aac1",
#             "status": "complete"
#           },
#           {
#             "id": 4,
#             "method": {
#               "id": 4,
#               "name": "HPLC"
#             },
#             "instrument": "b0e210ed-495e-4e0f-84bd-78eb270fac70",
#             "status": "complete"
#           }
#         ]
#       },
#       {
#         "id": 2,
#         "label": "MG-001-02",
#         "name": "Annealed Pd",
#         "measurement_sessions": [
#           {
#             "id": 8,
#             "method": {
#               "id": 1,
#               "name": "XPS"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 9,
#             "method": {
#               "id": 2,
#               "name": "XRD"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 10,
#             "method": {
#               "id": 3,
#               "name": "GC"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 11,
#             "method": {
#               "id": 4,
#               "name": "HPLC"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 12,
#             "method": {
#               "id": 5,
#               "name": "IR"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 13,
#             "method": {
#               "id": 6,
#               "name": "Raman"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 14,
#             "method": {
#               "id": 7,
#               "name": "ICP"
#             },
#             "instrument": null,
#             "status": "not started"
#           }
#         ]
#       },
#       {
#         "id": 3,
#         "label": "MG-001-03",
#         "name": "Activated Pd",
#         "measurement_sessions": [
#           {
#             "id": 15,
#             "method": {
#               "id": 1,
#               "name": "XPS"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 16,
#             "method": {
#               "id": 2,
#               "name": "XRD"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 17,
#             "method": {
#               "id": 3,
#               "name": "GC"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 18,
#             "method": {
#               "id": 4,
#               "name": "HPLC"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 19,
#             "method": {
#               "id": 5,
#               "name": "IR"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 20,
#             "method": {
#               "id": 6,
#               "name": "Raman"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 21,
#             "method": {
#               "id": 7,
#               "name": "ICP"
#             },
#             "instrument": null,
#             "status": "not started"
#           }
#         ]
#       },
#       {
#         "id": 4,
#         "label": "MG-001-04",
#         "name": "Used Pd",
#         "measurement_sessions": [
#           {
#             "id": 22,
#             "method": {
#               "id": 1,
#               "name": "XPS"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 23,
#             "method": {
#               "id": 2,
#               "name": "XRD"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 24,
#             "method": {
#               "id": 3,
#               "name": "GC"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 25,
#             "method": {
#               "id": 4,
#               "name": "HPLC"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 26,
#             "method": {
#               "id": 5,
#               "name": "IR"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 27,
#             "method": {
#               "id": 6,
#               "name": "Raman"
#             },
#             "instrument": null,
#             "status": "not started"
#           },
#           {
#             "id": 28,
#             "method": {
#               "id": 7,
#               "name": "ICP"
#             },
#             "instrument": null,
#             "status": "not started"
#           }
#         ]
#       }
#     ],
#     "configuration": 1
#   }
# ]

# %% [markdown]
# Again, let's put the result in a Dataframe.

# %%
studies_df = pd.DataFrame(studies)
display(studies_df)
# Out:
#    id   name         date_created  \
# 0   1  study  2021-09-21 13:40:08
#
#                                              samples  configuration
# 0  [{'id': 1, 'label': 'MG-001-01', 'name': None,...              1

# %% [markdown]
# Here we see very few results because the 'study' is the highest-level object. All the other objects are nested.
# Let's flatten it.

# %%
flat_studies_df = pd.json_normalize(studies[0]['samples'], sep='-')
display(flat_studies_df)
# Out:
#    id      label          name  \
# 0   1  MG-001-01          None
# 1   2  MG-001-02   Annealed Pd
# 2   3  MG-001-03  Activated Pd
# 3   4  MG-001-04       Used Pd
#
#                                 measurement_sessions
# 0  [{'id': 1, 'method': {'id': 1, 'name': 'XPS'},...
# 1  [{'id': 8, 'method': {'id': 1, 'name': 'XPS'},...
# 2  [{'id': 15, 'method': {'id': 1, 'name': 'XPS'}...
# 3  [{'id': 22, 'method': {'id': 1, 'name': 'XPS'}...
